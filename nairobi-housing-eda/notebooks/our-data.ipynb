# %%
import pandas as pd

# %%
df1 = pd.read_csv("../data/raw/nairobi-apts-1.csv")
df1.head()
# Out:
#                                               title  \
# 0          6 Bed Villa with En Suite at Kiambu Road
# 1  4 Bed Townhouse with En Suite at Off Kiambu Road
# 2     4 Bed Villa with En Suite at Masai Lodge Road
# 3           5 Bed House with En Suite in Ngong Road
# 4        5 Bed Townhouse with En Suite in Lavington
#
#                           location  \
# 0                      Kiambu Road
# 1     Off Kiambu Road, Kiambu Road
# 2  masai lodge road, Ongata Rongai
# 3                       Ngong Road
# 4                        Lavington
#
#                                                 size    selling price
# 0  6bdrm Mansion in Mushroom Estate, Kiambu / Kia...  KSh 130,000,000
# 1                        4 Bedroom with DSQ for Sale   KSh 26,950,000
# 2                         New modern villa for sale.   KSh 16,000,000
# 3          5 Bedroom Town House For Sale In Kilimani   KSh 45,000,000
# 4                Modern 5 Bedroom Townhouse For Sale   KSh 72,000,000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1876 entries, 0 to 1875
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1876 non-null   object
#  1   location       1876 non-null   object
#  2   size           1876 non-null   object
#  3   selling price  1876 non-null   object
# dtypes: object(4)
# memory usage: 58.8+ KB

# %%
df2 = pd.read_csv("../data/raw/nairobi-apts-2.csv")
df2.head()
# Out:
#    House_ID Location City_Town Type_of_House  Bedrooms  Bathrooms  \
# 0         1    Nyeri   Mathari     Townhouse         4          1
# 1         2  Mombasa    Mtwapa      Bungalow         2          2
# 2         3  Malindi   Mambrui         Villa         6          6
# 3         4  Nairobi     Karen     Apartment         3          3
# 4         5  Nairobi  Kilimani       Mansion         2          1
#
#    Lot_Size_sqft  House_Price_KSh  House_Tax_Rate_%  Year_Built  \
# 0           4410         55448692              4.60        1980
# 1           3343         23502404              3.49        1983
# 2            661         43510154              2.75        1994
# 3           4199         60259667              4.58        1988
# 4           2052         53670484              3.10        1981
#
#    Proximity_to_City_km  Price_Change_Since_2020_KSh  Price_2020_KSh  \
# 0                 35.58                     -9733534        49192658
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   House_ID                     11000 non-null  int64
#  1   Location                     11000 non-null  object
#  2   City_Town                    11000 non-null  object
#  3   Type_of_House                11000 non-null  object
#  4   Bedrooms                     11000 non-null  int64
#  5   Bathrooms                    11000 non-null  int64
#  6   Lot_Size_sqft                11000 non-null  int64
#  7   House_Price_KSh              11000 non-null  int64
#  8   House_Tax_Rate_%             11000 non-null  float64
#  9   Year_Built                   11000 non-null  int64
#  10  Proximity_to_City_km         11000 non-null  float64
#  11  Price_Change_Since_2020_KSh  11000 non-null  int64
#  12  Price_2020_KSh               11000 non-null  int64
# ...

# %%
df3 = pd.read_csv("../data/raw/nairobi-apts-3.csv")
df3.head()
# Out:
#                                 price             location  \
# 0    FromKSh 6 950 000toKSh 8 950 000      Riruta, Nairobi
# 1  FromKSh 12 000 000toKSh 16 500 000    Kilimani, Nairobi
# 2   FromKSh 8 000 000toKSh 11 500 000  Kileleshwa, Nairobi
# 3   FromKSh 9 500 000toKSh 10 000 000    Syokimau, Nairobi
# 4                                 POA  Kileleshwa, Nairobi
#
#               price_clean  price_numeric                      price_original  \
# 0    From6950000to8950000   6.950000e+12    FromKSh 6 950 000toKSh 8 950 000
# 1  From12000000to16500000   1.200000e+13  FromKSh 12 000 000toKSh 16 500 000
# 2   From8000000to11500000   8.000000e+12   FromKSh 8 000 000toKSh 11 500 000
# 3   From9500000to10000000   9.500000e+12   FromKSh 9 500 000toKSh 10 000 000
# 4                     POA            NaN                                 POA
#
#    price_outlier price_category       location_clean neighborhood city_region  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           50 non-null     object
#  1   location        50 non-null     object
#  2   price_clean     50 non-null     object
#  3   price_numeric   45 non-null     float64
#  4   price_original  50 non-null     object
#  5   price_outlier   50 non-null     bool
#  6   price_category  44 non-null     object
#  7   location_clean  50 non-null     object
#  8   neighborhood    50 non-null     object
#  9   city_region     50 non-null     object
#  10  processed_date  50 non-null     object
# dtypes: bool(1), float64(1), object(9)
# memory usage: 4.1+ KB

# %%
df4 = pd.read_csv("../data/raw/nairobi-apts-4.csv")
df4.head()
# Out:
#              Price propertyType    Location  Bedroom  bathroom House size  \
# 0  KSh 350 000 000    Townhouse       Runda      4.0       4.0        NaN
# 1   KSh 30 000 000  Vacant Land       Karen      NaN       NaN        NaN
# 2  KSh 325 000 000  Vacant Land   Westlands      NaN       NaN        NaN
# 3   KSh 80 000 000    Townhouse    Kitisuru      5.0       5.0        NaN
# 4   KSh 25 500 000    Apartment  Kileleshwa      4.0       4.0     230 m²
#
#    Land size
# 0  0.5 acres
# 1  0.5 acres
# 2  0.5 acres
# 3  0.5 acres
# 4        NaN

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         204 non-null    object
#  1   propertyType  204 non-null    object
#  2   Location      204 non-null    object
#  3   Bedroom       183 non-null    float64
#  4   bathroom      181 non-null    float64
#  5   House size    99 non-null     object
#  6   Land size     64 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 11.3+ KB

# %%
df5 = pd.read_csv("../data/raw/nairobi-apts-5.csv")
df5.head()
# Out:
#                    Agency                             Neighborhood  \
# 0       Buy Rent Shelters              General Mathenge, Westlands
# 1     Kenya Classic Homes                Kilimani, Dagoretti North
# 2  Absolute Estate Agents  Hatheru Rd,, Lavington, Dagoretti North
# 3   A1 Properties Limited                Kilimani, Dagoretti North
# 4     Pmc Estates Limited                    Imara Daima, Embakasi
#
#          Price                                               link  sq_mtrs  \
# 0  KSh 155,000  /listings/4-bedroom-apartment-for-rent-general...      4.0
# 1  KSh 100,000  /listings/3-bedroom-apartment-for-rent-kiliman...    300.0
# 2   KSh 75,000  /listings/3-bedroom-apartment-for-rent-lavingt...      3.0
# 3  KSh 135,000  /listings/3-bedroom-apartment-for-rent-kiliman...    227.0
# 4   KSh 50,000  /listings/3-bedroom-apartment-for-rent-imara-d...      3.0
#
#    Bedrooms  Bathrooms
# 0       4.0        4.0
# 1       3.0        4.0
# 2       3.0        5.0
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1848 entries, 0 to 1847
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Agency        1848 non-null   object
#  1   Neighborhood  1848 non-null   object
#  2   Price         1848 non-null   object
#  3   link          1848 non-null   object
#  4   sq_mtrs       1846 non-null   float64
#  5   Bedrooms      1845 non-null   float64
#  6   Bathrooms     1557 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 101.2+ KB
